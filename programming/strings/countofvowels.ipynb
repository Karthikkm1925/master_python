# %% [markdown]
# <strong style="font-size:30px;color:green">Count of Vowels in given String</strong>

# %%
s = input("Enter a string :")
print("You Entered :",s)
count = 0
for i in s:
    if i in "AEIOUaeiou":
        count+=1
print("Count of vowels :",count)
# Out:
# You Entered : programming
# Count of vowels : 3
