# %% [markdown]
# <strong style="font-size : 30px; color:green">Input and Output Function</strong>

# %% [markdown]
# <strong style="font-size:25px; color:green">Standard input using input()</strong>

# %%
#Standard input using input() function
variabl_name = input("Enter some text as input :\n") #input() function returns a string
print("Text You Entered is :\n",variabl_name) #Basic output function print()
# Out:
# Text You Entered is :
#  Python is Programming Language

# %% [markdown]
# <strong style="font-size:25px; color:green">Input type conversion to number using int()</strong>

# %%
#input() returns string need conversion, int() converts strint to number
#Number input
number = int(input("Enter a number :\n")) #Number input
print("The Number you Entered is :",number) #output
# Out:
# The Number you Entered is : 1234

# %% [markdown]
# <strong style="font-size:25px; color:green">Multiple inputs in one line using split()</strong>

# %%
num1,num2 = input("Enter two numbers : ").split()
print("The Two Numbers you Entered are :",num1,",",num2)
# Out:
# The Two Numbers you Entered are : 10 , 20

# %% [markdown]
# <strong style="font-size:25px; color:green">Multiple inputs in one line With type conversion using map()</strong>

# %%
num1,num2,num3 = map(int, input("Enter three numbers : ").split())
print("Entered Numbers are :",num1,num2,num3)
# Out:
# Entered Numbers are : 10 20 30

# %% [markdown]
# <strong style="font-size:25px; color:green">Taking list input using list()</strong>

# %%
numbers = list(map(int, input("Enter List of Numbers :").split()))
print("The List of Numbers you Entered are :\n",numbers)
# Out:
# The List of Numbers you Entered are :
#  [10, 20, 30, 40, 50]

# %% [markdown]
# <strong style="font-size:30px; color:green">Output methods in Python</strong>

# %% [markdown]
# <strong style="font-size:25px; color:green">Basic output</strong>

# %%
#Basic Output Method
print("Python programming")
# Out:
# Python programming

# %% [markdown]
# <strong style="font-size:25px; color:green">Printing Variables</strong>

# %%
#print(variable_name)
name = "Jacki Chan"
age = 45
print(name)
print(age)
# Out:
# Jacki Chan
# 45

# %% [markdown]
# <strong style="font-size:25px; color:green">Formatted output (f-strings)</strong>

# %%
person_name = "Alan"
print(f'Hi {person_name}')
# Out:
# Hi Alan

# %% [markdown]
# <strong style="font-size:25px; color:green">Printing Multiple Values</strong>

# %%
country_name = "India"
capital_city = "New Delhi"
print(capital_city,"is Capital of",country_name)
# Out:
# New Delhi is Capital of India

# %% [markdown]
# <strong style="font-size:25px; color:green">Using String Concatenation (+)</strong>

# %%
name = "Mickle"
print("My name is "+name)
# Out:
# My name is Mickle

# %% [markdown]
# <strong style="font-size:25px; color:green">Using .format()</strong>

# %%
name = "Henry ford"
age = 68
print("Hey {} is {} years old".format(name,age))
# Out:
# Hey Henry ford is 68 years old

# %% [markdown]
# <strong style="font-size:25px; color:green">Using % Formatting (Older Method)</strong>

# %%
name = "Tim John"
age = 32
print("Hey %s is just %d years old" % (name,age))
# Out:
# Hey Tim John is just 32 years old

# %% [markdown]
# <strong style="font-size:25px; color:green">Using sep</strong>

# %%
print("Java", "Python", "C++", sep="|")
# Out:
# Java|Python|C++

# %% [markdown]
# <strong style="font-size:25px; color:green">Using end</strong>

# %%
#Avoids new line
print("Hi,",end="")
print("How do you do")
# Out:
# Hi,How do you do

# %% [markdown]
# <strong style="font-size:25px; color:green">Multi-line Output</strong>

# %%
print('''These programming langauages
python
Java
C#
''')
# Out:
# These programming langauages
# python
# Java
# C#

# %% [markdown]
# <strong style="font-size:25px; color:green">Escape Characters</strong>

# %%
# \n represents new line
print("Hello\nWorld")
# Out:
# Hello
# World
